# %%
#IRIS dataset
import pandas as pd
print("Library has been imported successfully")
# Out:
# Library has been imported successfully

# %%
#read dataset "iris.csv"

data = pd.read_csv("iris.csv")

# %%
#display the top rows  with their columns
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2      NaN
# 1   2            4.9           3.0            1.4           0.2      NaN
# 2   3            4.7           3.2            1.3           0.2      NaN
# 3   4            4.6           3.1            1.5           0.2      NaN
# 4   5            5.0           3.6            1.4           0.2      NaN

# %%
#display random rows
data.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 149  150            5.9           3.0            5.1           1.8
# 83    84            6.0           2.7            5.1           1.6
# 42    43            4.4           3.2            1.3           0.2
# 17    18            5.1           3.5            1.4           0.3
# 89    90            5.5           2.5            4.0           1.3
# 33    34            5.5           4.2            1.4           0.2
# 113  114            5.7           2.5            5.0           2.0
# 51    52            6.4           3.2            4.5           1.5
# 101  102            5.8           2.7            5.1           1.9
# 68    69            6.2           2.2            4.5           1.5
#
#              Species
# 149   Iris-virginica
# 83   Iris-versicolor
# 42       Iris-setosa
# 17       Iris-setosa
# 89   Iris-versicolor
# 33       Iris-setosa
# 113   Iris-virginica
# 51   Iris-versicolor
# 101   Iris-virginica
# ...

# %%
#display the no of columns and names
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#display shape of dataset(rows,cols)
data.shape
# Out:
# (150, 6)

# %%
#count unique values
data['Species'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
#count unique values
data['SepalLengthCm'].value_counts().rename("SepalLengthCm")
# Out:
# SepalLengthCm
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 6.4     7
# 5.5     7
# 5.8     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 6.2     4
# 4.4     3
# 7.2     3
# 5.9     3
# 6.8     3
# 4.7     2
# 6.6     2
# 4.3     1
# 7.0     1
# 5.3     1
# 4.5     1
# 7.1     1
# 7.3     1
# 7.6     1
# 7.4     1
# 7.9     1
# Name: SepalLengthCm, dtype: int64

# %%
#cleaning and detecting missing values
data.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False     True
# 1    False          False         False          False         False     True
# 2    False          False         False          False         False     True
# 3    False          False         False          False         False     True
# 4    False          False         False          False         False     True
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False     True
# 146  False          False         False          False         False     True
# 147  False          False         False          False         False     True
# 148  False          False         False          False         False     True
# 149  False          False         False          False         False     True
#
# [150 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Id                 0
# SepalLengthCm      0
# SepalWidthCm       0
# PetalLengthCm      0
# PetalWidthCm       0
# Species          150
# dtype: int64

# %%
#correlation - pearson
data.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# Species             NaN            NaN           NaN            NaN
#
#                PetalWidthCm  Species
# Id                 0.899759      NaN
# SepalLengthCm      0.817954      NaN
# SepalWidthCm      -0.356544      NaN
# PetalLengthCm      0.962757      NaN
# PetalWidthCm       1.000000      NaN
# Species                 NaN      NaN

# %%
#import seaborn library
import seaborn as sns

sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(data.corr(), annot= True)
# Out:
# <Axes: >

# %%
#multivariate Analysis
sns.pairplot(data, hue = 'SepalLengthCm')
