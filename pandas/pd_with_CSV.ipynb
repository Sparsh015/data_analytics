# %%
import numpy as np
import pandas as pd

# %%
cars_per_cap = [809, 731, 588, 18, 200, 70, 45]
country = ['United states','Australia','Japan','India', 'Russia','Moroco','Egypt']
drives_right = [True,False,False,False,True,True,True]

# %%
data = {"cars_per_cap": cars_per_cap, "country": country, "drives_right" : drives_right}

# %%
data
# Out:
# {'cars_per_cap': [809, 731, 588, 18, 200, 70, 45],
#  'country': ['United states',
#   'Australia',
#   'Japan',
#   'India',
#   'Russia',
#   'Moroco',
#   'Egypt'],
#  'drives_right': [True, False, False, False, True, True, True]}

# %%
cars = pd.DataFrame(data)
cars
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United states          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70         Moroco          True
# 6            45          Egypt          True

# %%
data = pd.read_csv("D:/Python/Book.csv")
data
# Out:
#    Index      Customer Id First Name Last Name                Company  \
# 0      1  f8463F562c58a0E   Cheyenne    Waller          Mueller Group
# 1      2  F015Cc697A7fC44     Alisha     Marsh              Hood-Ross
# 2      3  ccfD2BEDbb7C58e      Lance    Dunlap              Bass-Carr
# 3      4  cdFbd68a8b6290f    Ricardo     Rojas        Barnett-Nielsen
# 4      5  8DfD5cc318e620a        Kim   Carlson       Mccullough-Eaton
# 5      6  6FCe9AF225A52b7   Danielle    Acosta  Shah, Avery and Miles
# 6      7  13B7eD7ADe53cea    Brianna     Stone     Fernandez and Sons
# 7      8  cfEF8CAe16842F1   Isabella   Bonilla             Conway Ltd
# 8      9  7b08206dE0163bD    Preston     Solis             Hart-Barry
# 9     10  cA0A8326b781CCB    Phillip    Knight          Barton-Dunlap
#
#               City                      Country                 Phone 1  \
# 0     Ortizchester                   Luxembourg              2868804914
# ...

# %%
#to not form a header since the first row becomes the header by default
data = pd.read_csv("D:/Python/Book.csv", header = None)
data
# Out:
#        0                1           2          3                      4   \
# 0   Index      Customer Id  First Name  Last Name                Company
# 1       1  f8463F562c58a0E    Cheyenne     Waller          Mueller Group
# 2       2  F015Cc697A7fC44      Alisha      Marsh              Hood-Ross
# 3       3  ccfD2BEDbb7C58e       Lance     Dunlap              Bass-Carr
# 4       4  cdFbd68a8b6290f     Ricardo      Rojas        Barnett-Nielsen
# 5       5  8DfD5cc318e620a         Kim    Carlson       Mccullough-Eaton
# 6       6  6FCe9AF225A52b7    Danielle     Acosta  Shah, Avery and Miles
# 7       7  13B7eD7ADe53cea     Brianna      Stone     Fernandez and Sons
# 8       8  cfEF8CAe16842F1    Isabella    Bonilla             Conway Ltd
# 9       9  7b08206dE0163bD     Preston      Solis             Hart-Barry
# 10     10  cA0A8326b781CCB     Phillip     Knight          Barton-Dunlap
#
#                  5                            6                       7   \
# ...

# %%
data = pd.read_csv("D:/Python/Book.csv")
data
# Out:
#    Index      Customer Id First Name Last Name                Company  \
# 0      1  f8463F562c58a0E   Cheyenne    Waller          Mueller Group
# 1      2  F015Cc697A7fC44     Alisha     Marsh              Hood-Ross
# 2      3  ccfD2BEDbb7C58e      Lance    Dunlap              Bass-Carr
# 3      4  cdFbd68a8b6290f    Ricardo     Rojas        Barnett-Nielsen
# 4      5  8DfD5cc318e620a        Kim   Carlson       Mccullough-Eaton
# 5      6  6FCe9AF225A52b7   Danielle    Acosta  Shah, Avery and Miles
# 6      7  13B7eD7ADe53cea    Brianna     Stone     Fernandez and Sons
# 7      8  cfEF8CAe16842F1   Isabella   Bonilla             Conway Ltd
# 8      9  7b08206dE0163bD    Preston     Solis             Hart-Barry
# 9     10  cA0A8326b781CCB    Phillip    Knight          Barton-Dunlap
#
#               City                      Country                 Phone 1  \
# 0     Ortizchester                   Luxembourg              2868804914
# ...

# %%
#columns name can be changed by
data.columns = ['b','c','d','e','f','g','h','i','j','k','l','m']
data
# Out:
#     b                c         d        e                      f  \
# 0   1  f8463F562c58a0E  Cheyenne   Waller          Mueller Group
# 1   2  F015Cc697A7fC44    Alisha    Marsh              Hood-Ross
# 2   3  ccfD2BEDbb7C58e     Lance   Dunlap              Bass-Carr
# 3   4  cdFbd68a8b6290f   Ricardo    Rojas        Barnett-Nielsen
# 4   5  8DfD5cc318e620a       Kim  Carlson       Mccullough-Eaton
# 5   6  6FCe9AF225A52b7  Danielle   Acosta  Shah, Avery and Miles
# 6   7  13B7eD7ADe53cea   Brianna    Stone     Fernandez and Sons
# 7   8  cfEF8CAe16842F1  Isabella  Bonilla             Conway Ltd
# 8   9  7b08206dE0163bD   Preston    Solis             Hart-Barry
# 9  10  cA0A8326b781CCB   Phillip   Knight          Barton-Dunlap
#
#                  g                            h                       i  \
# 0     Ortizchester                   Luxembourg              2868804914
# 1  East Isaiahport                      Reunion       536.961.6286x6057
# ...

# %%
data = pd.read_csv("D:/Python/Book.csv",index_col=0)
data
# Out:
#            Customer Id First Name Last Name                Company  \
# Index
# 1      f8463F562c58a0E   Cheyenne    Waller          Mueller Group
# 2      F015Cc697A7fC44     Alisha     Marsh              Hood-Ross
# 3      ccfD2BEDbb7C58e      Lance    Dunlap              Bass-Carr
# 4      cdFbd68a8b6290f    Ricardo     Rojas        Barnett-Nielsen
# 5      8DfD5cc318e620a        Kim   Carlson       Mccullough-Eaton
# 6      6FCe9AF225A52b7   Danielle    Acosta  Shah, Avery and Miles
# 7      13B7eD7ADe53cea    Brianna     Stone     Fernandez and Sons
# 8      cfEF8CAe16842F1   Isabella   Bonilla             Conway Ltd
# 9      7b08206dE0163bD    Preston     Solis             Hart-Barry
# 10     cA0A8326b781CCB    Phillip    Knight          Barton-Dunlap
#
#                   City                      Country                 Phone 1  \
# Index
# 1         Ortizchester                   Luxembourg              2868804914
# ...

# %%
data.index.name = 'INDEX'
data
# Out:
#            Customer Id First Name Last Name                Company  \
# INDEX
# 1      f8463F562c58a0E   Cheyenne    Waller          Mueller Group
# 2      F015Cc697A7fC44     Alisha     Marsh              Hood-Ross
# 3      ccfD2BEDbb7C58e      Lance    Dunlap              Bass-Carr
# 4      cdFbd68a8b6290f    Ricardo     Rojas        Barnett-Nielsen
# 5      8DfD5cc318e620a        Kim   Carlson       Mccullough-Eaton
# 6      6FCe9AF225A52b7   Danielle    Acosta  Shah, Avery and Miles
# 7      13B7eD7ADe53cea    Brianna     Stone     Fernandez and Sons
# 8      cfEF8CAe16842F1   Isabella   Bonilla             Conway Ltd
# 9      7b08206dE0163bD    Preston     Solis             Hart-Barry
# 10     cA0A8326b781CCB    Phillip    Knight          Barton-Dunlap
#
#                   City                      Country                 Phone 1  \
# INDEX
# 1         Ortizchester                   Luxembourg              2868804914
# ...
