# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('D:/Python/data_analytics/IIT_R UNGA.xlsx')
data
# Out:
#                    Countries DAY 1  DAY 2  GSL (10)  MOD 1 (10)  MOD 2(10)  \
# 0                Afghanistan   NaN    NaN       NaN         NaN        NaN
# 1                    Albania   NaN    NaN       NaN         NaN        NaN
# 2                  Australia    pv    NaN       NaN        5.50        NaN
# 3                    Belarus    pv    NaN       NaN        5.70        NaN
# 4                     Canada    pv    NaN       NaN        5.50        NaN
# 5                      China    pv    NaN      5.75        5.50        NaN
# 6                    Denmark    pv    NaN       NaN        5.50        NaN
# 7                     France    pv    NaN      5.95        6.00        NaN
# 8                    Germany    pv    NaN      5.65        6.00        NaN
# 9                      India    pv    NaN      5.70        5.75        NaN
# 10                      Iran    Pv    NaN       NaN        6.50        NaN
# ...
